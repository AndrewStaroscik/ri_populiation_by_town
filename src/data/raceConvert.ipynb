# %%
import pandas as pd

# %%
df = pd.read_csv('./ri2020byRace.csv')

# %%
df.to_json('./ri2020byRace.json')

# %%
df.head()
# Out:
#          cit_twn     One   White AfrAmer AIAN Asian  NH_PI  Other Two_or_more
# 0     Barrington  16,001  14,770     164    6   928    0.0    133       1,152
# 1        Bristol  21,467  20,510     424   70   233    1.0    229       1,026
# 2   Burrillville  15,399  14,986     105   24    79    8.0    197         759
# 3  Central Falls  17,509   6,308   1,687  523   134   17.0  8,840       5,074
# 4    Charlestown   7,601   7,344      37  112    50    1.0     57         396

# %%
df.set_index('cit_twn')
# Out:
#                       One    White AfrAmer   AIAN   Asian  NH_PI    Other  \
# cit_twn
# Barrington         16,001   14,770     164      6     928    0.0      133
# Bristol            21,467   20,510     424     70     233    1.0      229
# Burrillville       15,399   14,986     105     24      79    8.0      197
# Central Falls      17,509    6,308   1,687    523     134   17.0    8,840
# Charlestown         7,601    7,344      37    112      50    1.0       57
# Coventry           33,746   32,439     335     81     463   11.0      417
# Cranston           75,808   56,514   4,683    485   5,799   45.0    8,282
# Cumberland         34,130   30,521     752     72   1,473   14.0    1,298
# East Greenwich     13,430   12,275     158     12     828    4.0      153
# East Providence    42,510   36,474   2,547    199     996   17.0    2,277
# Exeter              6,148    5,945      26     23      70    1.0       83
# ...

# %%
df.to_json('./ri2020byRace.json')
